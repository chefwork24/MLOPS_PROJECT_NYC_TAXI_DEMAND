# %%
import mlflow

mlflow.set_tracking_uri("http://localhost:5000")

# TFT run ID from the output above
best_run_id = "e59623142461465080eecb7f01be7e42"

mlflow.register_model(
    model_uri=f"runs:/{best_run_id}/model",
    name="nyc-taxi-demand-model"
)
print("Model registered successfully")
# Out:
# Successfully registered model 'nyc-taxi-demand-model'.
# 2026/03/31 18:19:49 WARNING mlflow.tracking._model_registry.fluent: Run with id e59623142461465080eecb7f01be7e42 has no artifacts at artifact path 'model', registering model based on models:/m-d2ec5c9b85724262b647fd5c7faff50c instead
# 2026/03/31 18:19:49 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: nyc-taxi-demand-model, version 1
# Model registered successfully
# Created version '1' of model 'nyc-taxi-demand-model'.
